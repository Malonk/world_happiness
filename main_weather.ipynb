# %% [markdown]
# # API:

# %%
import pandas as pd
import requests
import json
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# ## Retrieving Global Weather Data: 2015-2019

# %% [markdown]
# ### LAT + LONG still requested for new Data API

# %% [markdown]
# #### Until this point API retrieval wasn't possible:
# #### See previous Jupyter Notebooks for further details

# %%
#On the morning of 28.08.2020 a solution to the collegues was proposed of stopping the previous API retrieval
#process and document it throughly and then continue with the direct download of CSV Historical Weather Data
#in order to present more material and be able to fullfill each one our correspoding work part. 
#Otherwise this wouldn't have been possible, the following is a result of that morning prior to presentation:

# %% [markdown]
# # Moving to 'CVS':
#
# ### *source: https://www.ncdc.noaa.gov/cdo-web/*

# %% [markdown]
# ## In order to start making conclusions from the retrieved data,
#
# ### Parameters are as follow:
#
#     Top 3 ranking countries in World Happiness for the years: 2015, 2016, 2017, 2019

# %%
#Following #complexity["some_key"][4]["another_key"]["one_more_key"][3][0]

df19 = pd.read_csv('Top_3_2019.csv')
df18 = pd.read_csv('Top_3_2018.csv')
df17 = pd.read_csv('Top_3_2017.csv')
df16 = pd.read_csv('Top_3_2016.csv')
df15 = pd.read_csv('Top_3_2015.csv')

# %%
df19
# Out:
#          STATION                         NAME  DATE   DSND   DX32  DX70  DX90  \
# 0    NOE00110860               STADLANDET, NO  2019    NaN    2.0  17.0   0.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2019  187.0    NaN   NaN   NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2019   17.0    NaN   NaN   NaN
# 3    NOE00132894                 UKKESTAD, NO  2019  139.0    NaN   NaN   NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2019   49.0    NaN   NaN   NaN
# ..           ...                          ...   ...    ...    ...   ...   ...
# 464  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2019    NaN  102.0  29.0   0.0
# 465  NOE00110779                   HAFSLO, NO  2019  130.0    NaN   NaN   NaN
# 466  FIE00146598      SALLA VARRIOTUNTURI, FI  2019    NaN  164.0  13.0   0.0
# 467  FIE00144057     VARKAUS KOSULANNIEMI, FI  2019    NaN   71.0  42.0   0.0
# 468  FIE00146117       KUUSAMO TEERIRANTA, FI  2019    NaN    NaN   NaN   NaN
#
#        PRCP  TAVG  TMAX  TMIN
# ...

# %% [markdown]
# ### Renaming Columns

# %%
df19 = df19.rename(columns={"STATION": "Station_ID","NAME": "Name","DATE": "Year","DSND":"Snow","DX32": "#<0C","DX70": "#>21.1C","DX90": "#>32.2C","TAVG": "Temp.Average", 
                            "PRCP": "Precipitation","TMAX": "Temp.Max", "TMIN": "Temp.Min"  })

# %%
df19
# Out:
#       Station_ID                         Name  Year   Snow   #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2019    NaN    2.0     17.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2019  187.0    NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2019   17.0    NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2019  139.0    NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2019   49.0    NaN      NaN
# ..           ...                          ...   ...    ...    ...      ...
# 464  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2019    NaN  102.0     29.0
# 465  NOE00110779                   HAFSLO, NO  2019  130.0    NaN      NaN
# 466  FIE00146598      SALLA VARRIOTUNTURI, FI  2019    NaN  164.0     13.0
# 467  FIE00144057     VARKAUS KOSULANNIEMI, FI  2019    NaN   71.0     42.0
# 468  FIE00146117       KUUSAMO TEERIRANTA, FI  2019    NaN    NaN      NaN
#
#      #>32.2C  Precipitation  Temp.Average  Temp.Max  Temp.Min
# ...

# %%
df18
# Out:
#          STATION                         NAME  DATE   DSND   DX32  DX70  DX90  \
# 0    NOE00110860               STADLANDET, NO  2018    NaN    6.0  23.0   0.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2018  150.0    NaN   NaN   NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2018   41.0    NaN   NaN   NaN
# 3    NOE00132894                 UKKESTAD, NO  2018  136.0    NaN   NaN   NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2018   76.0    NaN   NaN   NaN
# ..           ...                          ...   ...    ...    ...   ...   ...
# 470  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2018    NaN  123.0  58.0   2.0
# 471  NOE00110779                   HAFSLO, NO  2018  132.0    NaN   NaN   NaN
# 472  FIE00146598      SALLA VARRIOTUNTURI, FI  2018    NaN  151.0  30.0   0.0
# 473  FIE00144057     VARKAUS KOSULANNIEMI, FI  2018    NaN   99.0  74.0   0.0
# 474  FIE00146117       KUUSAMO TEERIRANTA, FI  2018    NaN    NaN   NaN   NaN
#
#        PRCP  TAVG  TMAX  TMIN
# ...

# %%
df18 = df18.rename(columns={"STATION": "Station_ID","NAME": "Name","DATE": "Year","DSND":"Snow","DX32": "#<0C","DX70": "#>21.1C","DX90": "#>32.2C","TAVG": "Temp.Average", 
                            "PRCP": "Precipitation","TMAX": "Temp.Max", "TMIN": "Temp.Min"  })

# %%
df18
# Out:
#       Station_ID                         Name  Year   Snow   #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2018    NaN    6.0     23.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2018  150.0    NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2018   41.0    NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2018  136.0    NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2018   76.0    NaN      NaN
# ..           ...                          ...   ...    ...    ...      ...
# 470  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2018    NaN  123.0     58.0
# 471  NOE00110779                   HAFSLO, NO  2018  132.0    NaN      NaN
# 472  FIE00146598      SALLA VARRIOTUNTURI, FI  2018    NaN  151.0     30.0
# 473  FIE00144057     VARKAUS KOSULANNIEMI, FI  2018    NaN   99.0     74.0
# 474  FIE00146117       KUUSAMO TEERIRANTA, FI  2018    NaN    NaN      NaN
#
#      #>32.2C  Precipitation  Temp.Average  Temp.Max  Temp.Min
# ...

# %%
df17
# Out:
#          STATION                    NAME  DATE   DSND  DX32  DX70  DX90  \
# 0    NOE00110860          STADLANDET, NO  2017    NaN   4.0   6.0   0.0
# 1    NOE00109993   KVIKNE I OSTERDAL, NO  2017  189.0   NaN   NaN   NaN
# 2    NOE00134154      LESJA SVANBORG, NO  2017  147.0   NaN   NaN   NaN
# 3    NOE00110500         FLEKKEFJORD, NO  2017    8.0   NaN   NaN   NaN
# 4    NOE00132894            UKKESTAD, NO  2017   73.0   NaN   NaN   NaN
# ..           ...                     ...   ...    ...   ...   ...   ...
# 291  NOE00110536  HUNDSEID I VIKEDAL, NO  2017    NaN   NaN   NaN   NaN
# 292  NOE00133638              HAFSAS, NO  2017  187.0   NaN   NaN   NaN
# 293  NOE00110779              HAFSLO, NO  2017  103.0   NaN   NaN   NaN
# 294  NOE00133518       OYSTESE BORGE, NO  2017   84.0   NaN   NaN   NaN
# 295  NOE00111192    LEKNES I LOFOTEN, NO  2017   80.0   NaN   NaN   NaN
#
#        PRCP  TAVG  TMAX  TMIN
# 0    3017.3   7.8  10.6   5.0
# 1     666.8   NaN   NaN   NaN
# ...

# %%
df17 = df17.rename(columns={"STATION": "Station_ID","NAME": "Name","DATE": "Year","DSND":"Snow","DX32": "#<0C","DX70": "#>21.1C","DX90": "#>32.2C","TAVG": "Temp.Average", 
                            "PRCP": "Precipitation","TMAX": "Temp.Max", "TMIN": "Temp.Min"  })

# %%
df17
# Out:
#       Station_ID                    Name  Year  #<0C  #>21.1C  #>32.2C  \
# 0    NOE00110860          STADLANDET, NO  2017   4.0      6.0      0.0
# 1    NOE00109993   KVIKNE I OSTERDAL, NO  2017   NaN      NaN      NaN
# 2    NOE00134154      LESJA SVANBORG, NO  2017   NaN      NaN      NaN
# 3    NOE00110500         FLEKKEFJORD, NO  2017   NaN      NaN      NaN
# 4    NOE00132894            UKKESTAD, NO  2017   NaN      NaN      NaN
# ..           ...                     ...   ...   ...      ...      ...
# 291  NOE00110536  HUNDSEID I VIKEDAL, NO  2017   NaN      NaN      NaN
# 292  NOE00133638              HAFSAS, NO  2017   NaN      NaN      NaN
# 293  NOE00110779              HAFSLO, NO  2017   NaN      NaN      NaN
# 294  NOE00133518       OYSTESE BORGE, NO  2017   NaN      NaN      NaN
# 295  NOE00111192    LEKNES I LOFOTEN, NO  2017   NaN      NaN      NaN
#
#      Precipitation  Temp.Average  Temp.Max  Temp.Min
# 0           3017.3           7.8      10.6       5.0
# ...

# %%
df16
# Out:
#         STATION                              NAME  DATE  DSND   DX32  DX70  \
# 0   SZ000002220                       SAENTIS, SZ  2016   NaN  152.0   0.0
# 1   DA000025140                   NORDBY FANO, DA  2016   NaN    NaN   NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2016   NaN   10.0  39.0
# 3   SZE00116090                       PAYERNE, SZ  2016   NaN    NaN   NaN
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2016   NaN    NaN   NaN
# 5   SZE00105086                        SION 2, SZ  2016   NaN    NaN   NaN
# 6   DAE00100416                STORE JYNDEVAD, DA  2016   NaN    NaN   NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2016   NaN    8.0  93.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2016   NaN    4.0  98.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2016   NaN   24.0   0.0
# 10  IC000004030                     REYKJAVIK, IC  2016   NaN   14.0   2.0
# ...

# %%
df16 = df16.rename(columns={"STATION": "Station_ID","NAME": "Name","DATE": "Year","DSND":"Snow","DX32": "#<0C","DX70": "#>21.1C","DX90": "#>32.2C","TAVG": "Temp.Average", 
                            "PRCP": "Precipitation","TMAX": "Temp.Max", "TMIN": "Temp.Min"  })

# %%
df16
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2016  152.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2016    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2016   10.0     39.0
# 3   SZE00116090                       PAYERNE, SZ  2016    NaN      NaN
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2016    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2016    NaN      NaN
# 6   DAE00100416                STORE JYNDEVAD, DA  2016    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2016    8.0     93.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2016    4.0     98.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2016   24.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2016   14.0      2.0
# 11  SZ000009480                        LUGANO, SZ  2016    NaN      NaN
# ...

# %%
df15
# Out:
#         STATION                              NAME  DATE   DSND   DX32   DX70  \
# 0   SZ000002220                       SAENTIS, SZ  2015  254.0  125.0    0.0
# 1   DA000025140                   NORDBY FANO, DA  2015    NaN    NaN    NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2015    NaN    4.0   28.0
# 3   SZE00116090                       PAYERNE, SZ  2015    8.0    8.0   97.0
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2015    NaN    NaN    NaN
# 5   SZE00105086                        SION 2, SZ  2015   19.0    1.0  135.0
# 6   DAE00100416                STORE JYNDEVAD, DA  2015    NaN    NaN    NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2015   34.0    9.0   90.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2015    0.0    1.0  102.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2015    NaN   38.0    0.0
# 10  IC000004030                     REYKJAVIK, IC  2015    NaN   31.0    0.0
# ...

# %%
df15 = df15.rename(columns={"STATION": "Station_ID","NAME": "Name","DATE": "Year","DSND":"Snow","DX32": "#<0C","DX70": "#>21.1C","DX90": "#>32.2C","TAVG": "Temp.Average", 
                            "PRCP": "Precipitation","TMAX": "Temp.Max", "TMIN": "Temp.Min"  })
df15
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2015  125.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2015    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2015    4.0     28.0
# 3   SZE00116090                       PAYERNE, SZ  2015    8.0     97.0
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2015    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2015    1.0    135.0
# 6   DAE00100416                STORE JYNDEVAD, DA  2015    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2015    9.0     90.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2015    1.0    102.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2015   38.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2015   31.0      0.0
# 11  SZ000009480                        LUGANO, SZ  2015    0.0    134.0
# ...

# %% [markdown]
# ### Understanding NaN Values

# %%
df19.shape
# Out:
# (469, 11)

# %%
df19.isna().sum()
# Out:
# Station_ID         0
# Name               0
# Year               0
# Snow             315
# #<0C             245
# #>21.1C          245
# #>32.2C          245
# Precipitation     86
# Temp.Average     245
# Temp.Max         245
# Temp.Min         245
# dtype: int64

# %%
df18.shape
# Out:
# (475, 11)

# %%
df18.isna().sum()
# Out:
# Station_ID         0
# Name               0
# Year               0
# Snow             326
# #<0C             265
# #>21.1C          265
# #>32.2C          265
# Precipitation     77
# Temp.Average     265
# Temp.Max         265
# Temp.Min         263
# dtype: int64

# %%
df17.shape
# Out:
# (296, 11)

# %%
df17.isna().sum()
# Out:
# Station_ID         0
# Name               0
# Year               0
# Snow             128
# #<0C             196
# #>21.1C          196
# #>32.2C          196
# Precipitation     43
# Temp.Average     197
# Temp.Max         196
# Temp.Min         195
# dtype: int64

# %%
df16.shape
# Out:
# (18, 11)

# %%
df16.isna().sum()
# Out:
# Station_ID        0
# Name              0
# Year              0
# Snow             18
# #<0C             10
# #>21.1C          10
# #>32.2C          10
# Precipitation     4
# Temp.Average     12
# Temp.Max         10
# Temp.Min         10
# dtype: int64

# %%
df15.shape
# Out:
# (17, 11)

# %%
df15.isna().sum()
# Out:
# Station_ID        0
# Name              0
# Year              0
# Snow             10
# #<0C              6
# #>21.1C           6
# #>32.2C           6
# Precipitation     1
# Temp.Average      6
# Temp.Max          6
# Temp.Min          4
# dtype: int64

# %%
#Since in most Data Frames the column DSND is missing most values, dropping DSND
#DSND stands for Number days with snow depth

df19= df19.drop(columns=['Snow'])
df19
# Out:
#       Station_ID                         Name  Year   #<0C  #>21.1C  #>32.2C  \
# 0    NOE00110860               STADLANDET, NO  2019    2.0     17.0      0.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2019    NaN      NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2019    NaN      NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2019    NaN      NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2019    NaN      NaN      NaN
# ..           ...                          ...   ...    ...      ...      ...
# 464  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2019  102.0     29.0      0.0
# 465  NOE00110779                   HAFSLO, NO  2019    NaN      NaN      NaN
# 466  FIE00146598      SALLA VARRIOTUNTURI, FI  2019  164.0     13.0      0.0
# 467  FIE00144057     VARKAUS KOSULANNIEMI, FI  2019   71.0     42.0      0.0
# 468  FIE00146117       KUUSAMO TEERIRANTA, FI  2019    NaN      NaN      NaN
#
# ...

# %%
df18= df18.drop(columns=['Snow'])
df18
# Out:
#       Station_ID                         Name  Year   #<0C  #>21.1C  #>32.2C  \
# 0    NOE00110860               STADLANDET, NO  2018    6.0     23.0      0.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2018    NaN      NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2018    NaN      NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2018    NaN      NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2018    NaN      NaN      NaN
# ..           ...                          ...   ...    ...      ...      ...
# 470  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2018  123.0     58.0      2.0
# 471  NOE00110779                   HAFSLO, NO  2018    NaN      NaN      NaN
# 472  FIE00146598      SALLA VARRIOTUNTURI, FI  2018  151.0     30.0      0.0
# 473  FIE00144057     VARKAUS KOSULANNIEMI, FI  2018   99.0     74.0      0.0
# 474  FIE00146117       KUUSAMO TEERIRANTA, FI  2018    NaN      NaN      NaN
#
# ...

# %%
df17= df17.drop(columns=['Snow'])
df17
# Out:
#       Station_ID                    Name  Year  #<0C  #>21.1C  #>32.2C  \
# 0    NOE00110860          STADLANDET, NO  2017   4.0      6.0      0.0
# 1    NOE00109993   KVIKNE I OSTERDAL, NO  2017   NaN      NaN      NaN
# 2    NOE00134154      LESJA SVANBORG, NO  2017   NaN      NaN      NaN
# 3    NOE00110500         FLEKKEFJORD, NO  2017   NaN      NaN      NaN
# 4    NOE00132894            UKKESTAD, NO  2017   NaN      NaN      NaN
# ..           ...                     ...   ...   ...      ...      ...
# 291  NOE00110536  HUNDSEID I VIKEDAL, NO  2017   NaN      NaN      NaN
# 292  NOE00133638              HAFSAS, NO  2017   NaN      NaN      NaN
# 293  NOE00110779              HAFSLO, NO  2017   NaN      NaN      NaN
# 294  NOE00133518       OYSTESE BORGE, NO  2017   NaN      NaN      NaN
# 295  NOE00111192    LEKNES I LOFOTEN, NO  2017   NaN      NaN      NaN
#
#      Precipitation  Temp.Average  Temp.Max  Temp.Min
# 0           3017.3           7.8      10.6       5.0
# ...

# %%
df16= df16.drop(columns=['Snow'])
df16
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2016  152.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2016    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2016   10.0     39.0
# 3   SZE00116090                       PAYERNE, SZ  2016    NaN      NaN
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2016    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2016    NaN      NaN
# 6   DAE00100416                STORE JYNDEVAD, DA  2016    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2016    8.0     93.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2016    4.0     98.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2016   24.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2016   14.0      2.0
# 11  SZ000009480                        LUGANO, SZ  2016    NaN      NaN
# ...

# %%
df15= df15.drop(columns=['Snow'])
df15
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2015  125.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2015    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2015    4.0     28.0
# 3   SZE00116090                       PAYERNE, SZ  2015    8.0     97.0
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2015    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2015    1.0    135.0
# 6   DAE00100416                STORE JYNDEVAD, DA  2015    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2015    9.0     90.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2015    1.0    102.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2015   38.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2015   31.0      0.0
# 11  SZ000009480                        LUGANO, SZ  2015    0.0    134.0
# ...

# %% [markdown]
# ### Drop II

# %%
#the column #>32.2C (DX32) gives us the number of days where the temperature is less than 32.
#this doesn't represent significantly useful information comprared to the columns that , for such reasons, dropping #>32.2C

# %%
df19= df19.drop(columns=['#>32.2C'])

# %%
df19
# Out:
#       Station_ID                         Name  Year   #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2019    2.0     17.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2019    NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2019    NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2019    NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2019    NaN      NaN
# ..           ...                          ...   ...    ...      ...
# 464  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2019  102.0     29.0
# 465  NOE00110779                   HAFSLO, NO  2019    NaN      NaN
# 466  FIE00146598      SALLA VARRIOTUNTURI, FI  2019  164.0     13.0
# 467  FIE00144057     VARKAUS KOSULANNIEMI, FI  2019   71.0     42.0
# 468  FIE00146117       KUUSAMO TEERIRANTA, FI  2019    NaN      NaN
#
#      Precipitation  Temp.Average  Temp.Max  Temp.Min
# 0           2294.5           7.8      10.8       4.8
# ...

# %%
df18= df18.drop(columns=['#>32.2C'])
df18
# Out:
#       Station_ID                         Name  Year   #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2018    6.0     23.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2018    NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2018    NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2018    NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2018    NaN      NaN
# ..           ...                          ...   ...    ...      ...
# 470  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2018  123.0     58.0
# 471  NOE00110779                   HAFSLO, NO  2018    NaN      NaN
# 472  FIE00146598      SALLA VARRIOTUNTURI, FI  2018  151.0     30.0
# 473  FIE00144057     VARKAUS KOSULANNIEMI, FI  2018   99.0     74.0
# 474  FIE00146117       KUUSAMO TEERIRANTA, FI  2018    NaN      NaN
#
#      Precipitation  Temp.Average  Temp.Max  Temp.Min
# 0           2413.9           7.8      10.8       4.7
# ...

# %%
df17= df17.drop(columns=['#>32.2C'])
df17
# Out:
#       Station_ID                    Name  Year  #<0C  #>21.1C  Precipitation  \
# 0    NOE00110860          STADLANDET, NO  2017   4.0      6.0         3017.3
# 1    NOE00109993   KVIKNE I OSTERDAL, NO  2017   NaN      NaN          666.8
# 2    NOE00134154      LESJA SVANBORG, NO  2017   NaN      NaN          463.8
# 3    NOE00110500         FLEKKEFJORD, NO  2017   NaN      NaN         2824.1
# 4    NOE00132894            UKKESTAD, NO  2017   NaN      NaN         1005.7
# ..           ...                     ...   ...   ...      ...            ...
# 291  NOE00110536  HUNDSEID I VIKEDAL, NO  2017   NaN      NaN         4237.8
# 292  NOE00133638              HAFSAS, NO  2017   NaN      NaN          791.3
# 293  NOE00110779              HAFSLO, NO  2017   NaN      NaN         1158.5
# 294  NOE00133518       OYSTESE BORGE, NO  2017   NaN      NaN         2761.1
# 295  NOE00111192    LEKNES I LOFOTEN, NO  2017   NaN      NaN         1372.5
#
#      Temp.Average  Temp.Max  Temp.Min
# ...

# %%
df16= df16.drop(columns=['#>32.2C'])
df16
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2016  152.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2016    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2016   10.0     39.0
# 3   SZE00116090                       PAYERNE, SZ  2016    NaN      NaN
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2016    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2016    NaN      NaN
# 6   DAE00100416                STORE JYNDEVAD, DA  2016    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2016    8.0     93.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2016    4.0     98.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2016   24.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2016   14.0      2.0
# 11  SZ000009480                        LUGANO, SZ  2016    NaN      NaN
# ...

# %%
df15= df15.drop(columns=['#>32.2C'])
df15
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2015  125.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2015    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2015    4.0     28.0
# 3   SZE00116090                       PAYERNE, SZ  2015    8.0     97.0
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2015    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2015    1.0    135.0
# 6   DAE00100416                STORE JYNDEVAD, DA  2015    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2015    9.0     90.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2015    1.0    102.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2015   38.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2015   31.0      0.0
# 11  SZ000009480                        LUGANO, SZ  2015    0.0    134.0
# ...

# %% [markdown]
# ## Understanding Max and Min values for ea/country in ea/year

# %%
#Where:  
    
#DX32 - Number days with maximum temperature < 32 F.
#DSND - Number days with snow depth > 1 inch(25.4mm) for the period.
#TMAX - Maximum temperature
#TAVG - Average Temperature.
#TMIN - Minimum temperature
#PRCP - Precipitation
#DX90 - Number days with maximum temperature > 90 F (32.2C)
#DX70 - Number days with maximum temperature > 70 F (21.1C)

# %%
For getting the max value of a column: dataframe.max()
For getting the min value of a column: dataframe.min()

# %% [markdown]
# ## Max. Values: Precipitation, <0C for each year

# %%
df19_pre= df19['Precipitation']
df19_0= df19['#<0C']

# %%
#Max value of precipitation for top countries 2019
max_value_pre19 = df19_pre.max()
max_value_pre19
# Out:
# 3156.5

# %%
#Max value of days below 0 Celcius Grads for top countries 2019
max_value_019 = df19_0.max()
max_value_019
# Out:
# 216.0

# %%
df18_pre= df18['Precipitation']
df18_0= df18['#<0C']

# %%
#Max value of precipitation for top countries 2018
max_value_pre18 = df18_pre.max()
max_value_pre18
# Out:
# 3418.3

# %%
#Max value of days below 0 Celcius Grads for top countries 2018
max_value_018 = df18_0.max()
max_value_018
# Out:
# 203.0

# %%
df17_pre= df17['Precipitation']
df17_0= df17['#<0C']

# %%
#Max value of precipitation for top countries 2017
max_value_pre17 = df17_pre.max()
max_value_pre17
# Out:
# 4237.8

# %%
#Max value of days below 0 Celcius Grads for top countries 2017
max_value_017 = df17_0.max()
max_value_017
# Out:
# 186.0

# %%
df16_pre= df16['Precipitation']
df16_0= df16['#<0C']

# %%
#Max value of precipitation for top countries 2016
max_value_pre16 = df16_pre.max()
max_value_pre16
# Out:
# 2960.9

# %%
#Max value of days below 0 Celcius Grads for top countries 2016
max_value_016 = df16_0.max()
max_value_016
# Out:
# 152.0

# %%
df15_pre= df15['Precipitation']
df15_0= df15['#<0C']

# %%
#Max value of precipitation for top countries 2015
max_value_pre15 = df15_pre.max()
max_value_pre15
# Out:
# 2389.8

# %%
#Max value of days below 0 Celcius Grads for top countries 2016
max_value_015 = df15_0.max()
max_value_015
152.0
# Out:
# 152.0

# %% [markdown]
# ## Min. Values:  Precipitation

# %%
#Min value of precipitation for top countries 2019
min_value_pre19 = df19_pre.min()
min_value_pre19
# Out:
# 291.9

# %%
#Min value of precipitation for top countries 2018
min_value_pre18 = df18_pre.min()
min_value_pre18
# Out:
# 232.6

# %%
#Min value of precipitation for top countries 2017
min_value_pre17 = df17_pre.min()
min_value_pre17
# Out:
# 286.0

# %%
#Min value of precipitation for top countries 2016
min_value_pre16 = df16_pre.min()
min_value_pre16
# Out:
# 557.2

# %%
#Min value of precipitation for top countries 2015
min_value_pre15 = df15_pre.min()
min_value_pre15
# Out:
# 500.1

# %% [markdown]
# ## Replacing NaN Values

# %%
#From observing the data frames and the operation to see how many nan values where present, some of the columns that 
#relevant to the analysis have NaN values, since dropping this columns might affect the analysis instead
#replacing NaN value with "Unknown".

# %%
df19
# Out:
#       Station_ID                         Name  Year   #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2019    2.0     17.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2019    NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2019    NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2019    NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2019    NaN      NaN
# ..           ...                          ...   ...    ...      ...
# 464  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2019  102.0     29.0
# 465  NOE00110779                   HAFSLO, NO  2019    NaN      NaN
# 466  FIE00146598      SALLA VARRIOTUNTURI, FI  2019  164.0     13.0
# 467  FIE00144057     VARKAUS KOSULANNIEMI, FI  2019   71.0     42.0
# 468  FIE00146117       KUUSAMO TEERIRANTA, FI  2019    NaN      NaN
#
#      Precipitation  Temp.Average  Temp.Max  Temp.Min
# 0           2294.5           7.8      10.8       4.8
# ...

# %%
df19['#<0C'].fillna('Unknown', inplace=True)
df19['#>21.1C'].fillna('Unknown', inplace=True)
df19['Precipitation'].fillna('Unknown', inplace=True)
df19['Temp.Average'].fillna('Unknown', inplace=True)
df19['Temp.Max'].fillna('Unknown', inplace=True)
df19['Temp.Min'].fillna('Unknown', inplace=True)
df19
# Out:
#       Station_ID                         Name  Year     #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2019        2       17
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2019  Unknown  Unknown
# 2    NOE00110500              FLEKKEFJORD, NO  2019  Unknown  Unknown
# 3    NOE00132894                 UKKESTAD, NO  2019  Unknown  Unknown
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2019  Unknown  Unknown
# ..           ...                          ...   ...      ...      ...
# 464  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2019      102       29
# 465  NOE00110779                   HAFSLO, NO  2019  Unknown  Unknown
# 466  FIE00146598      SALLA VARRIOTUNTURI, FI  2019      164       13
# 467  FIE00144057     VARKAUS KOSULANNIEMI, FI  2019       71       42
# 468  FIE00146117       KUUSAMO TEERIRANTA, FI  2019  Unknown  Unknown
#
#     Precipitation Temp.Average Temp.Max Temp.Min
# 0          2294.5          7.8     10.8      4.8
# ...

# %%
df18
# Out:
#       Station_ID                         Name  Year   #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2018    6.0     23.0
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2018    NaN      NaN
# 2    NOE00110500              FLEKKEFJORD, NO  2018    NaN      NaN
# 3    NOE00132894                 UKKESTAD, NO  2018    NaN      NaN
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2018    NaN      NaN
# ..           ...                          ...   ...    ...      ...
# 470  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2018  123.0     58.0
# 471  NOE00110779                   HAFSLO, NO  2018    NaN      NaN
# 472  FIE00146598      SALLA VARRIOTUNTURI, FI  2018  151.0     30.0
# 473  FIE00144057     VARKAUS KOSULANNIEMI, FI  2018   99.0     74.0
# 474  FIE00146117       KUUSAMO TEERIRANTA, FI  2018    NaN      NaN
#
#      Precipitation  Temp.Average  Temp.Max  Temp.Min
# 0           2413.9           7.8      10.8       4.7
# ...

# %%
df18['#<0C'].fillna('Unknown', inplace=True)
df18['#>21.1C'].fillna('Unknown', inplace=True)
df18['Precipitation'].fillna('Unknown', inplace=True)
df18['Temp.Average'].fillna('Unknown', inplace=True)
df18['Temp.Max'].fillna('Unknown', inplace=True)
df18['Temp.Min'].fillna('Unknown', inplace=True)
df18
# Out:
#       Station_ID                         Name  Year     #<0C  #>21.1C  \
# 0    NOE00110860               STADLANDET, NO  2018        6       23
# 1    NOE00109993        KVIKNE I OSTERDAL, NO  2018  Unknown  Unknown
# 2    NOE00110500              FLEKKEFJORD, NO  2018  Unknown  Unknown
# 3    NOE00132894                 UKKESTAD, NO  2018  Unknown  Unknown
# 4    NOE00109876        MOSS BRANNSTASJON, NO  2018  Unknown  Unknown
# ..           ...                          ...   ...      ...      ...
# 470  FIE00146241  ROVANIEMI RAUTATIEASEMA, FI  2018      123       58
# 471  NOE00110779                   HAFSLO, NO  2018  Unknown  Unknown
# 472  FIE00146598      SALLA VARRIOTUNTURI, FI  2018      151       30
# 473  FIE00144057     VARKAUS KOSULANNIEMI, FI  2018       99       74
# 474  FIE00146117       KUUSAMO TEERIRANTA, FI  2018  Unknown  Unknown
#
#     Precipitation Temp.Average Temp.Max Temp.Min
# 0          2413.9          7.8     10.8      4.7
# ...

# %%
df17
# Out:
#       Station_ID                    Name  Year  #<0C  #>21.1C  Precipitation  \
# 0    NOE00110860          STADLANDET, NO  2017   4.0      6.0         3017.3
# 1    NOE00109993   KVIKNE I OSTERDAL, NO  2017   NaN      NaN          666.8
# 2    NOE00134154      LESJA SVANBORG, NO  2017   NaN      NaN          463.8
# 3    NOE00110500         FLEKKEFJORD, NO  2017   NaN      NaN         2824.1
# 4    NOE00132894            UKKESTAD, NO  2017   NaN      NaN         1005.7
# ..           ...                     ...   ...   ...      ...            ...
# 291  NOE00110536  HUNDSEID I VIKEDAL, NO  2017   NaN      NaN         4237.8
# 292  NOE00133638              HAFSAS, NO  2017   NaN      NaN          791.3
# 293  NOE00110779              HAFSLO, NO  2017   NaN      NaN         1158.5
# 294  NOE00133518       OYSTESE BORGE, NO  2017   NaN      NaN         2761.1
# 295  NOE00111192    LEKNES I LOFOTEN, NO  2017   NaN      NaN         1372.5
#
#      Temp.Average  Temp.Max  Temp.Min
# ...

# %%
df17['#<0C'].fillna('Unknown', inplace=True)
df17['#>21.1C'].fillna('Unknown', inplace=True)
df17['Precipitation'].fillna('Unknown', inplace=True)
df17['Temp.Average'].fillna('Unknown', inplace=True)
df17['Temp.Max'].fillna('Unknown', inplace=True)
df17['Temp.Min'].fillna('Unknown', inplace=True)
df17
# Out:
#       Station_ID                    Name  Year     #<0C  #>21.1C  \
# 0    NOE00110860          STADLANDET, NO  2017        4        6
# 1    NOE00109993   KVIKNE I OSTERDAL, NO  2017  Unknown  Unknown
# 2    NOE00134154      LESJA SVANBORG, NO  2017  Unknown  Unknown
# 3    NOE00110500         FLEKKEFJORD, NO  2017  Unknown  Unknown
# 4    NOE00132894            UKKESTAD, NO  2017  Unknown  Unknown
# ..           ...                     ...   ...      ...      ...
# 291  NOE00110536  HUNDSEID I VIKEDAL, NO  2017  Unknown  Unknown
# 292  NOE00133638              HAFSAS, NO  2017  Unknown  Unknown
# 293  NOE00110779              HAFSLO, NO  2017  Unknown  Unknown
# 294  NOE00133518       OYSTESE BORGE, NO  2017  Unknown  Unknown
# 295  NOE00111192    LEKNES I LOFOTEN, NO  2017  Unknown  Unknown
#
#     Precipitation Temp.Average Temp.Max Temp.Min
# 0          3017.3          7.8     10.6        5
# 1           666.8      Unknown  Unknown  Unknown
# ...

# %%
df16
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2016  152.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2016    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2016   10.0     39.0
# 3   SZE00116090                       PAYERNE, SZ  2016    NaN      NaN
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2016    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2016    NaN      NaN
# 6   DAE00100416                STORE JYNDEVAD, DA  2016    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2016    8.0     93.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2016    4.0     98.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2016   24.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2016   14.0      2.0
# 11  SZ000009480                        LUGANO, SZ  2016    NaN      NaN
# ...

# %%
df16['#<0C'].fillna('Unknown', inplace=True)
df16['#>21.1C'].fillna('Unknown', inplace=True)
df16['Precipitation'].fillna('Unknown', inplace=True)
df16['Temp.Average'].fillna('Unknown', inplace=True)
df16['Temp.Max'].fillna('Unknown', inplace=True)
df16['Temp.Min'].fillna('Unknown', inplace=True)
df16
# Out:
#      Station_ID                              Name  Year     #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2016      152        0
# 1   DA000025140                   NORDBY FANO, DA  2016  Unknown  Unknown
# 2   DAE00100980              TRANEBJERG OST 1, DA  2016       10       39
# 3   SZE00116090                       PAYERNE, SZ  2016  Unknown  Unknown
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2016  Unknown  Unknown
# 5   SZE00105086                        SION 2, SZ  2016  Unknown  Unknown
# 6   DAE00100416                STORE JYNDEVAD, DA  2016  Unknown  Unknown
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2016        8       93
# 8   SZ000001940               BASEL BINNINGEN, SZ  2016        4       98
# 9   IC000004013                 STYKKISHOLMUR, IC  2016       24        0
# 10  IC000004030                     REYKJAVIK, IC  2016       14        2
# 11  SZ000009480                        LUGANO, SZ  2016  Unknown  Unknown
# ...

# %%
df15
# Out:
#      Station_ID                              Name  Year   #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2015  125.0      0.0
# 1   DA000025140                   NORDBY FANO, DA  2015    NaN      NaN
# 2   DAE00100980              TRANEBJERG OST 1, DA  2015    4.0     28.0
# 3   SZE00116090                       PAYERNE, SZ  2015    8.0     97.0
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2015    NaN      NaN
# 5   SZE00105086                        SION 2, SZ  2015    1.0    135.0
# 6   DAE00100416                STORE JYNDEVAD, DA  2015    NaN      NaN
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2015    9.0     90.0
# 8   SZ000001940               BASEL BINNINGEN, SZ  2015    1.0    102.0
# 9   IC000004013                 STYKKISHOLMUR, IC  2015   38.0      0.0
# 10  IC000004030                     REYKJAVIK, IC  2015   31.0      0.0
# 11  SZ000009480                        LUGANO, SZ  2015    0.0    134.0
# ...

# %%
df15['#<0C'].fillna('Unknown', inplace=True)
df15['#>21.1C'].fillna('Unknown', inplace=True)
df15['Precipitation'].fillna('Unknown', inplace=True)
df15['Temp.Average'].fillna('Unknown', inplace=True)
df15['Temp.Max'].fillna('Unknown', inplace=True)
df15['Temp.Min'].fillna('Unknown', inplace=True)
df15
# Out:
#      Station_ID                              Name  Year     #<0C  #>21.1C  \
# 0   SZ000002220                       SAENTIS, SZ  2015      125        0
# 1   DA000025140                   NORDBY FANO, DA  2015  Unknown  Unknown
# 2   DAE00100980              TRANEBJERG OST 1, DA  2015        4       28
# 3   SZE00116090                       PAYERNE, SZ  2015        8       97
# 4   DA000030370      KOEBENHAVN BOTANISK HAVE, DA  2015  Unknown  Unknown
# 5   SZE00105086                        SION 2, SZ  2015        1      135
# 6   DAE00100416                STORE JYNDEVAD, DA  2015  Unknown  Unknown
# 7   SZ000003700              ZUERICH FLUNTERN, SZ  2015        9       90
# 8   SZ000001940               BASEL BINNINGEN, SZ  2015        1      102
# 9   IC000004013                 STYKKISHOLMUR, IC  2015       38        0
# 10  IC000004030                     REYKJAVIK, IC  2015       31        0
# 11  SZ000009480                        LUGANO, SZ  2015        0      134
# ...

# %% [markdown]
# #### Since limits in time in order to present the information for evalutation are present
# #### the data cleaning process is stopped here, yet below are suggestions of possible ways to further
# #### clean the data if the opportunity is available:
#
#     -Replace Station ID with country name
#     -Merge tables in order to have all information present in one to be directly comparable to the WHR

# %% [markdown]
#                                         *Charlotte Velilla 28.08.20*
